# %%
print(ord('a'))
# Out:
# 97

# %%
'ABC'.encode('ascii')
# Out:
# b'ABC'

# %%
'ABzw中文'.encode('UTF-8')
# Out:
# b'ABzw\xe4\xb8\xad\xe6\x96\x87'

# %%
print('%2d-%02d' % (3, 1))
# Out:
#  3-01

# %%
'hello, {0}, upgrade {1:.1f}%'.format('world', 17.125)
# Out:
# 'hello, world, upgrade 17.1%'

# %%
r =  (85/72-1)*100
print('%.1f %%' % r)
# Out:
# 18.1 %

# %% [markdown]
# 去年的72分提升到了今年的85分，请计算小明成绩提升的百分点，并用字符串格式化显示出'xx.x%'，只保留小数点后1位：

# %%
classmates = ['Michael', 'Bob', 'Tracy']

# %% [markdown]
# list数据类型

# %%
classmates.append('Adam')

# %% [markdown]
# 删除list末尾的元素，用pop()

# %%
classmates.pop()
# Out:
# 'Adam'

# %% [markdown]
# 只有1个元素的tuple定义时必须加一个逗号,，来消除歧义

# %%
t = (1, )

# %% [markdown]
# 可变的”tuple”

# %%
t = ('a', 'b', ['A', 'B'])
t[2][0] = 'X'
print(t)
# Out:
# ('a', 'b', ['X', 'B'])

# %%
L = [
    ['Apple', 'Google', 'Microsoft'],
    ['Java', 'Python', 'Ruby', 'PHP'],
    ['Adam', 'Bart', 'Bob']
]
print(L[0][0])
print(L[1][1])
# Out:
# Apple
# Python

# %% [markdown]
# dict: 字典 键值对存储

# %%
d = {'Michael': 95, 'Bob': 75, 'Tracy': 85}
print(d['Michael'])
# Out:
# 95

# %%
d['Bob']=90
print(d['Bob'])
# Out:
# 90

# %%
d.get('Bob')
print(d.get('Bob')) #判断是否包含键Bob
# Out:
# 90

# %%
d.pop('Bob')
print(d)
# Out:
# {'Michael': 95, 'Tracy': 85}

# %% [markdown]
# set和dict类似，也是一组key的集合，但不存储value。由于key不能重复，所以，在set中，没有重复的key。

# %%
s = set([1, 2, 3]) 
s = {1, 2, 3}#都可以

# %% [markdown]
# str是不变对象，而list是可变对象

# %%
a = ['c', 'b', 'a']
a.sort()
print(a)
# Out:
# ['a', 'b', 'c']

# %%
a = 'abc'
print(a.replace('a', 'A'))
print(a)
# Out:
# Abc
# abc
